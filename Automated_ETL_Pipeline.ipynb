# %% [markdown]
# # Automated ETL Pipeline (Extract, Transform, Load)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install prefect
# Out:
# Requirement already satisfied: prefect in d:\anaconda3\lib\site-packages (3.4.25)
# Requirement already satisfied: aiosqlite<1.0.0,>=0.17.0 in d:\anaconda3\lib\site-packages (from prefect) (0.21.0)
# Requirement already satisfied: alembic<2.0.0,>=1.7.5 in d:\anaconda3\lib\site-packages (from prefect) (1.17.1)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (4.7.0)
# Requirement already satisfied: apprise<2.0.0,>=1.1.0 in d:\anaconda3\lib\site-packages (from prefect) (1.9.5)
# Requirement already satisfied: asgi-lifespan<3.0,>=1.0 in d:\anaconda3\lib\site-packages (from prefect) (2.1.0)
# Requirement already satisfied: asyncpg<1.0.0,>=0.23 in d:\anaconda3\lib\site-packages (from prefect) (0.30.0)
# Requirement already satisfied: cachetools<7.0,>=5.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (5.5.2)
# Requirement already satisfied: click<9,>=8.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (8.1.8)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in d:\anaconda3\lib\site-packages (from prefect) (2.2.1)
# Requirement already satisfied: coolname<3.0.0,>=1.0.4 in d:\anaconda3\lib\site-packages (from prefect) (2.2.0)
# Requirement already satisfied: cryptography>=36.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (44.0.0)
# Requirement already satisfied: dateparser<2.0.0,>=1.1.1 in d:\anaconda3\lib\site-packages (from prefect) (1.2.2)
# Requirement already satisfied: docker<8.0,>=4.0 in d:\anaconda3\lib\site-packages (from prefect) (7.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in d:\anaconda3\lib\site-packages (from prefect) (1.3.0)
# Requirement already satisfied: fastapi<1.0.0,>=0.111.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (0.115.6)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (2025.3.2)
# Requirement already satisfied: graphviz>=0.20.1 in d:\anaconda3\lib\site-packages (from prefect) (0.21)
# Requirement already satisfied: griffe<2.0.0,>=0.49.0 in d:\anaconda3\lib\site-packages (from prefect) (1.14.0)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (1.0.7)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (0.28.1)
# Requirement already satisfied: humanize<5.0.0,>=4.9.0 in d:\anaconda3\lib\site-packages (from prefect) (4.14.0)
# Requirement already satisfied: jinja2-humanize-extension>=0.4.0 in d:\anaconda3\lib\site-packages (from prefect) (0.4.0)
# Collecting jinja2<4.0.0,>=3.1.6 (from prefect)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in d:\anaconda3\lib\site-packages (from prefect) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (4.23.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.27.0 in d:\anaconda3\lib\site-packages (from prefect) (1.38.0)
# Requirement already satisfied: orjson<4.0,>=3.7 in d:\anaconda3\lib\site-packages (from prefect) (3.11.4)
# Requirement already satisfied: packaging<25.1,>=21.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (24.2)
# Requirement already satisfied: pathspec>=0.8.0 in d:\anaconda3\lib\site-packages (from prefect) (0.10.3)
# Requirement already satisfied: pendulum<4,>=3.0.0 in d:\anaconda3\lib\site-packages (from prefect) (3.1.0)
# Requirement already satisfied: pluggy>=1.6.0 in d:\anaconda3\lib\site-packages (from prefect) (1.6.0)
# Requirement already satisfied: prometheus-client>=0.20.0 in d:\anaconda3\lib\site-packages (from prefect) (0.23.1)
# Requirement already satisfied: pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (2.10.4)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (2.27.2)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.8.2 in d:\anaconda3\lib\site-packages (from prefect) (2.10.6)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>2.2.1 in d:\anaconda3\lib\site-packages (from prefect) (2.11.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in d:\anaconda3\lib\site-packages (from prefect) (5.0.2)
# Requirement already satisfied: pytz<2026,>=2021.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (2025.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (6.0.2)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in d:\anaconda3\lib\site-packages (from prefect) (4.2.1)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in d:\anaconda3\lib\site-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<15.0,>=11.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (14.0.0)
# Requirement already satisfied: ruamel-yaml>=0.17.0 in d:\anaconda3\lib\site-packages (from prefect) (0.17.21)
# Requirement already satisfied: semver>=3.0.4 in d:\anaconda3\lib\site-packages (from prefect) (3.0.4)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (1.3.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (2.0.36)
# Requirement already satisfied: toml>=0.10.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (0.10.2)
# Requirement already satisfied: typer!=0.12.2,<0.20.0,>=0.12.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (0.15.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (4.14.1)
# Requirement already satisfied: uv>=0.6.0 in d:\anaconda3\lib\site-packages (from prefect) (0.9.7)
# Requirement already satisfied: uvicorn!=0.29.0,>=0.14.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (0.34.0)
# Requirement already satisfied: websockets<16.0,>=15.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from prefect) (15.0.1)
# Requirement already satisfied: Mako in d:\anaconda3\lib\site-packages (from alembic<2.0.0,>=1.7.5->prefect) (1.3.10)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from anyio<5.0.0,>=4.4.0->prefect) (3.7)
# Requirement already satisfied: requests in c:\users\dell\appdata\roaming\python\python312\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.32.3)
# Requirement already satisfied: requests-oauthlib in d:\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.0.0)
# Requirement already satisfied: markdown in c:\users\dell\appdata\roaming\python\python312\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (3.8)
# Requirement already satisfied: certifi in c:\users\dell\appdata\roaming\python\python312\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.7.14)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\roaming\python\python312\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.2)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from click<9,>=8.0->prefect) (0.4.6)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\dell\appdata\roaming\python\python312\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (5.3.1)
# Requirement already satisfied: pywin32>=304 in c:\users\dell\appdata\roaming\python\python312\site-packages (from docker<8.0,>=4.0->prefect) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from docker<8.0,>=4.0->prefect) (2.5.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from fastapi<1.0.0,>=0.111.0->prefect) (0.41.3)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpcore<2.0.0,>=1.0.5->prefect) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from jinja2<4.0.0,>=3.1.6->prefect) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.32->prefect) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\appdata\roaming\python\python312\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\appdata\roaming\python\python312\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.24.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.27.0->prefect) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.27.0->prefect) (3.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1->prefect) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pydantic-settings!=2.9.0,<3.0.0,>2.2.1->prefect) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic-settings!=2.9.0,<3.0.0,>2.2.1->prefect) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.8.2->prefect) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in d:\anaconda3\lib\site-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from rich<15.0,>=11.0->prefect) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from rich<15.0,>=11.0->prefect) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sqlalchemy<3.0.0,>=2.0->sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (3.1.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from typer!=0.12.2,<0.20.0,>=0.12.0->prefect) (1.5.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\dell\appdata\roaming\python\python312\site-packages (from cryptography>=36.0.1->prefect) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\roaming\python\python312\site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.22)
# Requirement already satisfied: h2<5,>=3 in d:\anaconda3\lib\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in d:\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in d:\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (4.1.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=11.0->prefect) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from requests->apprise<2.0.0,>=1.1.0->prefect) (3.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib->apprise<2.0.0,>=1.1.0->prefect) (3.3.1)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Installing collected packages: jinja2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
# Successfully installed jinja2-3.1.6
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.5.1 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.4.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'D:\anaconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\anaconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from prefect import flow, task
import os

# %%
#Extract
# This step reads multiple CSV files (like GDP, Population, etc.)
# from the given folder and loads them into pandas DataFrames.

@task
def extract_data(file_path: str):
    """
    Extract Step:
    Reads the electricity access dataset (CSV file) into a pandas DataFrame.
    """
    print("\nExtracting data from CSV file...")

    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        return None

    df = pd.read_csv(file_path)
    print(f"Loaded dataset with {len(df)} rows and {len(df.columns)} columns.")
    return df

# %%
#Transform
# This step cleans, merges, and enriches the data.
# Here we merge GDP and Population data, clean columns, and calculate GDP per capita.

def transform_data(df: pd.DataFrame):
    """
    Transform Step:
    Cleans the dataset and adds calculated insights.
    """
    print("\nTransforming data...")

    # Remove rows with missing values
    df_cleaned = df.dropna()

    # Standardize column names (remove spaces)
    df_cleaned.columns = df_cleaned.columns.str.strip().str.replace(" ", "_")

    # Example transformation: Calculate global mean electricity access for each year
    if "Electricity_Access_Percent" in df_cleaned.columns:
        df_cleaned["Above_Global_Avg"] = df_cleaned["Electricity_Access_Percent"] > df_cleaned["Electricity_Access_Percent"].mean()

    print(f"Cleaned data shape: {df_cleaned.shape}")
    return df_cleaned

# %%
#Load
# This step saves the cleaned and transformed data into a new CSV file.

@task
def load_data(df: pd.DataFrame, output_path="cleaned_electricity_data.csv"):
    """
    Load Step:
    Saves the transformed dataset to a CSV file.
    """
    if df is not None:
        df.to_csv(output_path, index=False)
        print(f"\nData successfully saved to: {output_path}")
    else:
        print("\nNo data to save!")

# %%
#ETL Pipeline Flow
# This is the main function that controls the entire ETL process:
# 1. Extract → 2. Transform → 3. Load

@flow
def etl_pipeline():
    """
    Full ETL Pipeline for Electricity Access Data.
    Extract → Transform → Load
    """
    print("\nStarting Automated ETL Pipeline...\n")

    # Step 1: Extract
    file_path = "electricity_access_percent.csv"  # Change path if needed
    df = extract_data(file_path)

    # Step 2: Transform
    cleaned_df = transform_data(df)

    # Step 3: Load
    load_data(cleaned_df)

    print("\nETL Pipeline completed successfully!")

# %%
etl_pipeline()

# %%
#run in the terminal 
# prefect server start
